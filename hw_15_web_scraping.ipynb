# %% [markdown]
# # Домашнее задание к лекции "Основы веб-скрапинга и работы с API"

# %% [markdown]
# ## Задание 1.
#
# ### Обязательная часть

# %% [markdown]
# Будем парсить страницу со свежеми новостям на [habr.com/ru/all/](https://habr.com/ru/all/).
#
# Вам необходимо собирать только те статьи, в которых встречается хотя бы одно требуемое ключевое слово. Эти слова определяем в начале кода в переменной, например:
#
# `KEYWORDS = ['python', 'парсинг']`
#
#  Поиск вести по всей доступной preview-информации (это информация, доступная непосредственно с текущей страницы).
#
# В итоге должен формироваться датафрейм вида: `<дата> - <заголовок> - <ссылка>`

# %%
import requests
import time
from bs4 import BeautifulSoup
import pandas as pd

# %%
keywords = ['python', 'парсинг']
url = 'https://habr.com/ru/all/'

# %%
def news(url, keywords):
    r = requests.get(url)
    time.sleep(0.2)
    soup = BeautifulSoup(r.text, 'html.parser')
    articles = soup.find_all('article', class_='post post_preview')
    
    filtered = [a for a in articles for k in keywords if k in a.text.lower()]         
    blocks = [f.find('a', class_='post__title_link') for f in filtered]
    dates = [f.find('span', class_='post__time').text for f in filtered]
    links = [b.attrs.get('href') for b in blocks]
    titles = [b.text for b in blocks]

    df = pd.DataFrame(list(zip(dates, titles, links)), columns=['дата', 'заголовок', 'ссылка'])
    
    return df

# %%
news(url, keywords)
# Out:
#               дата                                          заголовок  \
# 0  сегодня в 17:01  Конвертеры маршрутов в Django 2.0+ (path conve...
#
#                                               ссылка
# 0  https://habr.com/ru/company/yandex_praktikum/b...

# %% [markdown]
# ## Задание 2.

# %% [markdown]
# ### Обязательная часть

# %% [markdown]
# Написать скрипт, который будет проверять список e-mail адресов на утечку при помощи сервиса [Avast Hack Ckeck](https://www.avast.com/hackcheck/).
# Список email-ов задаем переменной в начале кода:
# `EMAIL = [xxx@x.ru, yyy@y.com]`
#
# В итоге должен формироваться датафрейм со столбцами: `<почта> - <дата утечки> - <источник утечки> - <описание утечки>`
#
# **Подсказка**: сервис работает при помощи "скрытого" API. Внимательно изучите post-запросы.

# %%
import requests
import json
import pandas as pd

# %%
email = ['xxx@x.ru', 'yyy@y.com']
url = 'https://identityprotection.avast.com/v1/web/query/site-breaches/unauthorized-data'

# %%
func(url, email)
# Out:
#         почта           дата утечки   источник утечки  \
# 0    xxx@x.ru  2017-02-14T00:00:00Z    parapa.mail.ru
# 1    xxx@x.ru  2016-10-21T00:00:00Z         adobe.com
# 2    xxx@x.ru  2017-01-31T00:00:00Z  cdprojektred.com
# 3    xxx@x.ru  2020-01-03T00:00:00Z     azcentral.com
# 4    xxx@x.ru  2016-10-21T00:00:00Z      linkedin.com
# 5    xxx@x.ru  2016-10-24T00:00:00Z       dropbox.com
# 6    xxx@x.ru  2020-05-28T00:00:00Z       wishbone.io
# 7    xxx@x.ru  2017-03-24T00:00:00Z         youku.com
# 8    xxx@x.ru  2017-11-04T00:00:00Z    myheritage.com
# 9    xxx@x.ru  2017-03-01T00:00:00Z      rayli.com.cn
# 10   xxx@x.ru  2019-06-13T00:00:00Z         canva.com
# 11   xxx@x.ru  2017-03-15T00:00:00Z    globalreach.eu
# 12   xxx@x.ru  2017-02-14T00:00:00Z     cfire.mail.ru
# 13   xxx@x.ru  2016-10-29T00:00:00Z            vk.com
# 14   xxx@x.ru  2018-02-18T00:00:00Z        netlog.com
# 15   xxx@x.ru  2016-10-23T00:00:00Z         imesh.com
# 16   xxx@x.ru  2019-10-17T00:00:00Z         zynga.com
# 17  yyy@y.com  2017-02-14T00:00:00Z    parapa.mail.ru
# 18  yyy@y.com  2016-10-21T00:00:00Z         adobe.com
# 19  yyy@y.com  2017-01-31T00:00:00Z  cdprojektred.com
# 20  yyy@y.com  2020-01-03T00:00:00Z     azcentral.com
# 21  yyy@y.com  2016-10-21T00:00:00Z      linkedin.com
# 22  yyy@y.com  2016-10-24T00:00:00Z       dropbox.com
# 23  yyy@y.com  2020-05-28T00:00:00Z       wishbone.io
# 24  yyy@y.com  2017-03-24T00:00:00Z         youku.com
# 25  yyy@y.com  2017-11-04T00:00:00Z    myheritage.com
# 26  yyy@y.com  2017-03-01T00:00:00Z      rayli.com.cn
# 27  yyy@y.com  2019-06-13T00:00:00Z         canva.com
# 28  yyy@y.com  2017-03-15T00:00:00Z    globalreach.eu
# 29  yyy@y.com  2017-02-14T00:00:00Z     cfire.mail.ru
# 30  yyy@y.com  2016-10-29T00:00:00Z            vk.com
# 31  yyy@y.com  2018-02-18T00:00:00Z        netlog.com
# 32  yyy@y.com  2016-10-23T00:00:00Z         imesh.com
# 33  yyy@y.com  2019-10-17T00:00:00Z         zynga.com
#
#                                       описание утечки
# 0   In July and August 2016, two criminals execute...
# 1   In October of 2013, criminals penetrated Adobe...
# 2   In March 2016, CDProjektRed.com.com's forum da...
# 3   At an unconfirmed date, online Arizona newspap...
# 4   In 2012, online professional networking platfo...
# 5   Cloud storage company Dropbox suffered a major...
# 6   In January 2020, the online poll website Wishb...
# 7   Youku is a large Chinese video content company...
# 8   In October 2017, a customer database belonging...
# 9   On an unconfirmed date, Chinese gossip site Ra...
# 10  In May 2019, graphic-design site Canva's datab...
# 11  In 2016, Global Reach Technology's database wa...
# 12  In July and August of 2016, two criminals carr...
# 13  Popular Russian social networking platform VKo...
# 14  Netlog (formerly known as Facebox and Bingbox)...
# 15  In June 2016, a cache of over 51 million user ...
# 16  In September 2019, the game developer Zynga wa...
# 17  In July and August 2016, two criminals execute...
# 18  In October of 2013, criminals penetrated Adobe...
# 19  In March 2016, CDProjektRed.com.com's forum da...
# 20  At an unconfirmed date, online Arizona newspap...
# 21  In 2012, online professional networking platfo...
# 22  Cloud storage company Dropbox suffered a major...
# 23  In January 2020, the online poll website Wishb...
# 24  Youku is a large Chinese video content company...
# 25  In October 2017, a customer database belonging...
# 26  On an unconfirmed date, Chinese gossip site Ra...
# 27  In May 2019, graphic-design site Canva's datab...
# 28  In 2016, Global Reach Technology's database wa...
# 29  In July and August of 2016, two criminals carr...
# 30  Popular Russian social networking platform VKo...
# 31  Netlog (formerly known as Facebox and Bingbox)...
# 32  In June 2016, a cache of over 51 million user ...
# 33  In September 2019, the game developer Zynga wa...

# %%
def func(url, email):   
    params = {'emailAddresses': email}
    headers={'Vaar-Version': '0', 'Vaar-Header-App-Product': 'hackcheck-web-avast'}
    r = requests.post(url, json=params, headers=headers)
    rj = r.json()
    results = {}
    list_ = []
    for x in rj['data']:
        d = rj['data'][x]
        em = next(iter(d))
        id = rj['data'][x][em][0]['breachId']
        list_.append(id)
        results[em] = list_

    email_col = []
    date_col = []
    descr_col = []
    site_col = []
    for es, ids in results.items():
        for i in ids:
            email_col.append(es)
            date_col.append(rj['breaches'][str(i)]['publishDate'])
            descr_col.append(rj['breaches'][str(i)]['description'])
            site_col.append(rj['breaches'][str(i)]['site'])

    df = pd.DataFrame(list(zip(email_col, date_col, site_col, descr_col)), columns=['почта', 'дата утечки', 'источник утечки', 'описание утечки'])
    return df
